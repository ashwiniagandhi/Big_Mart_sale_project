# %% [markdown]
# # Import required library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings  # Ignores any warning
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load dataset

# %%
train=pd.read_csv(r"C:\Users\SAGAR\Documents\ashwini\latest_project\avishkar\assignment\projects\proj1big mart sale project\train.csv")
train.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
# 7            Snack Foods  107.7622            OUT027
# 8           Frozen Foods   96.9726            OUT045
# 9           Frozen Foods  187.8214            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# 5                       2009      Medium               Tier 3
# 6                       1987        High               Tier 3
# 7                       1985      Medium               Tier 3
# 8                       2002         NaN               Tier 2
# 9                       2007         NaN               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
# 5  Supermarket Type2           556.6088
# 6  Supermarket Type1           343.5528
# 7  Supermarket Type3          4022.7636
# 8  Supermarket Type1          1076.5986
# 9  Supermarket Type1          4710.5350

# %%
test=pd.read_csv(r"C:\Users\SAGAR\Documents\ashwini\latest_project\avishkar\assignment\projects\proj1big mart sale project\Test.csv")
test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007         NaN               Tier 2
# 2                          1998         NaN               Tier 3
# 3                          2007         NaN               Tier 2
# 4                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002         NaN               Tier 2
# 5679                       2007         NaN               Tier 2
# 5680                       2002         NaN               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
train.size
# Out:
# 102276

# %%
train.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
train.shape
# Out:
# (8523, 12)

# %%
test.shape
# Out:
# (5681, 11)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
a=[train,test]
a
# Out:
# [     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
#  0              FDA15        9.300          Low Fat         0.016047
#  1              DRC01        5.920          Regular         0.019278
#  2              FDN15       17.500          Low Fat         0.016760
#  3              FDX07       19.200          Regular         0.000000
#  4              NCD19        8.930          Low Fat         0.000000
#  ...              ...          ...              ...              ...
#  8518           FDF22        6.865          Low Fat         0.056783
#  8519           FDS36        8.380          Regular         0.046982
#  8520           NCJ29       10.600          Low Fat         0.035186
#  8521           FDN46        7.210          Regular         0.145221
#  8522           DRG01       14.800          Low Fat         0.044878
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
#  0                     Dairy  249.8092            OUT049
#  1               Soft Drinks   48.2692            OUT018
#  2                      Meat  141.6180            OUT049
#  3     Fruits and Vegetables  182.0950            OUT010
#  4                 Household   53.8614            OUT013
#  ...                     ...       ...               ...
#  8518            Snack Foods  214.5218            OUT013
#  8519           Baking Goods  108.1570            OUT045
#  8520     Health and Hygiene   85.1224            OUT035
#  8521            Snack Foods  103.1332            OUT018
#  8522            Soft Drinks   75.4670            OUT046
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
#  0                          1999      Medium               Tier 1
#  1                          2009      Medium               Tier 3
#  2                          1999      Medium               Tier 1
#  3                          1998         NaN               Tier 3
#  4                          1987        High               Tier 3
#  ...                         ...         ...                  ...
#  8518                       1987        High               Tier 3
#  8519                       2002         NaN               Tier 2
#  8520                       2004       Small               Tier 2
#  8521                       2009      Medium               Tier 3
#  8522                       1997       Small               Tier 1
#
#              Outlet_Type  Item_Outlet_Sales
#  0     Supermarket Type1          3735.1380
#  1     Supermarket Type2           443.4228
#  2     Supermarket Type1          2097.2700
#  3         Grocery Store           732.3800
#  4     Supermarket Type1           994.7052
#  ...                 ...                ...
#  8518  Supermarket Type1          2778.3834
#  8519  Supermarket Type1           549.2850
#  8520  Supermarket Type1          1193.1136
#  8521  Supermarket Type2          1845.5976
#  8522  Supermarket Type1           765.6700
#
#  [8523 rows x 12 columns],
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
#  0              FDW58       20.750          Low Fat         0.007565
#  1              FDW14        8.300              reg         0.038428
#  2              NCN55       14.600          Low Fat         0.099575
#  3              FDQ58        7.315          Low Fat         0.015388
#  4              FDY38          NaN          Regular         0.118599
#  ...              ...          ...              ...              ...
#  5676           FDB58       10.500          Regular         0.013496
#  5677           FDD47        7.600          Regular         0.142991
#  5678           NCO17       10.000          Low Fat         0.073529
#  5679           FDJ26       15.300          Regular         0.000000
#  5680           FDU37        9.500          Regular         0.104720
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
#  0            Snack Foods  107.8622            OUT049
#  1                  Dairy   87.3198            OUT017
#  2                 Others  241.7538            OUT010
#  3            Snack Foods  155.0340            OUT017
#  4                  Dairy  234.2300            OUT027
#  ...                  ...       ...               ...
#  5676         Snack Foods  141.3154            OUT046
#  5677       Starchy Foods  169.1448            OUT018
#  5678  Health and Hygiene  118.7440            OUT045
#  5679              Canned  214.6218            OUT017
#  5680              Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
#  0                          1999      Medium               Tier 1
#  1                          2007         NaN               Tier 2
#  2                          1998         NaN               Tier 3
#  3                          2007         NaN               Tier 2
#  4                          1985      Medium               Tier 3
#  ...                         ...         ...                  ...
#  5676                       1997       Small               Tier 1
#  5677                       2009      Medium               Tier 3
#  5678                       2002         NaN               Tier 2
#  5679                       2007         NaN               Tier 2
#  5680                       2002         NaN               Tier 2
#
#              Outlet_Type
#  0     Supermarket Type1
#  1     Supermarket Type1
#  2         Grocery Store
#  3     Supermarket Type1
#  4     Supermarket Type3
#  ...                 ...
#  5676  Supermarket Type1
#  5677  Supermarket Type2
#  5678  Supermarket Type1
#  5679  Supermarket Type1
#  5680  Supermarket Type1
#
#  [5681 rows x 11 columns]]

# %% [markdown]
# # concat train test data

# %%
df = pd.concat(a, ignore_index=True)
print(train.shape, test.shape, df.shape)
# Out:
# (8523, 12) (5681, 11) (14204, 12)

# %%
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
# ...                      ...       ...               ...
# 14199            Snack Foods  141.3154            OUT046
# 14200          Starchy Foods  169.1448            OUT018
# 14201     Health and Hygiene  118.7440            OUT045
# 14202                 Canned  214.6218            OUT017
# 14203                 Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                           1999      Medium               Tier 1
# 1                           2009      Medium               Tier 3
# 2                           1999      Medium               Tier 1
# 3                           1998         NaN               Tier 3
# 4                           1987        High               Tier 3
# ...                          ...         ...                  ...
# 14199                       1997       Small               Tier 1
# 14200                       2009      Medium               Tier 3
# 14201                       2002         NaN               Tier 2
# 14202                       2007         NaN               Tier 2
# 14203                       2002         NaN               Tier 2
#
#              Outlet_Type  Item_Outlet_Sales
# 0      Supermarket Type1          3735.1380
# 1      Supermarket Type2           443.4228
# 2      Supermarket Type1          2097.2700
# 3          Grocery Store           732.3800
# 4      Supermarket Type1           994.7052
# ...                  ...                ...
# 14199  Supermarket Type1                NaN
# 14200  Supermarket Type2                NaN
# 14201  Supermarket Type1                NaN
# 14202  Supermarket Type1                NaN
# 14203  Supermarket Type1                NaN
#
# [14204 rows x 12 columns]

# %%
df.dtypes=='object'
# Out:
# Item_Identifier               True
# Item_Weight                  False
# Item_Fat_Content              True
# Item_Visibility              False
# Item_Type                     True
# Item_MRP                     False
# Outlet_Identifier             True
# Outlet_Establishment_Year    False
# Outlet_Size                   True
# Outlet_Location_Type          True
# Outlet_Type                   True
# Item_Outlet_Sales            False
# dtype: bool

# %%
Unique = len(set(df.Item_Identifier))
Unique
# Out:
# 1559

# %%
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
# ...                      ...       ...               ...
# 14199            Snack Foods  141.3154            OUT046
# 14200          Starchy Foods  169.1448            OUT018
# 14201     Health and Hygiene  118.7440            OUT045
# 14202                 Canned  214.6218            OUT017
# 14203                 Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                           1999      Medium               Tier 1
# 1                           2009      Medium               Tier 3
# 2                           1999      Medium               Tier 1
# 3                           1998         NaN               Tier 3
# 4                           1987        High               Tier 3
# ...                          ...         ...                  ...
# 14199                       1997       Small               Tier 1
# 14200                       2009      Medium               Tier 3
# 14201                       2002         NaN               Tier 2
# 14202                       2007         NaN               Tier 2
# 14203                       2002         NaN               Tier 2
#
#              Outlet_Type  Item_Outlet_Sales
# 0      Supermarket Type1          3735.1380
# 1      Supermarket Type2           443.4228
# 2      Supermarket Type1          2097.2700
# 3          Grocery Store           732.3800
# 4      Supermarket Type1           994.7052
# ...                  ...                ...
# 14199  Supermarket Type1                NaN
# 14200  Supermarket Type2                NaN
# 14201  Supermarket Type1                NaN
# 14202  Supermarket Type1                NaN
# 14203  Supermarket Type1                NaN
#
# [14204 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
features_nan=[feature for feature in df.columns if df[feature].isnull().sum()>1 and df[feature].dtypes=='O']
for feature in features_nan:
    print("{}: {}% missing values".format(feature,np.round(df[feature].isnull().mean(),4)))
# Out:
# Outlet_Size: 0.2827% missing values

# %%
pd.isnull(df['Item_Identifier'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14199    False
# 14200    False
# 14201    False
# 14202    False
# 14203    False
# Name: Item_Identifier, Length: 14204, dtype: bool

# %%
pd.isnull(df['Item_Weight']).sum()
# Out:
# 2439

# %%
df.fillna(method ='bfill')
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
# ...                      ...       ...               ...
# 14199            Snack Foods  141.3154            OUT046
# 14200          Starchy Foods  169.1448            OUT018
# 14201     Health and Hygiene  118.7440            OUT045
# 14202                 Canned  214.6218            OUT017
# 14203                 Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                           1999      Medium               Tier 1
# 1                           2009      Medium               Tier 3
# 2                           1999      Medium               Tier 1
# 3                           1998        High               Tier 3
# 4                           1987        High               Tier 3
# ...                          ...         ...                  ...
# 14199                       1997       Small               Tier 1
# 14200                       2009      Medium               Tier 3
# 14201                       2002         NaN               Tier 2
# 14202                       2007         NaN               Tier 2
# 14203                       2002         NaN               Tier 2
#
#              Outlet_Type  Item_Outlet_Sales
# 0      Supermarket Type1          3735.1380
# 1      Supermarket Type2           443.4228
# 2      Supermarket Type1          2097.2700
# 3          Grocery Store           732.3800
# 4      Supermarket Type1           994.7052
# ...                  ...                ...
# 14199  Supermarket Type1                NaN
# 14200  Supermarket Type2                NaN
# 14201  Supermarket Type1                NaN
# 14202  Supermarket Type1                NaN
# 14203  Supermarket Type1                NaN
#
# [14204 rows x 12 columns]

# %%
len(df)
# Out:
# 14204

# %%
df['Item_Weight'].fillna(method ='ffill',inplace=True)

# %%
df["Item_Weight"].fillna(df['Item_Weight'].mean(), inplace = True)

# %%
df["Outlet_Size"].fillna(method='ffill', inplace = True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
df.Outlet_Type.value_counts()
# Out:
# Supermarket Type1    9294
# Grocery Store        1805
# Supermarket Type3    1559
# Supermarket Type2    1546
# Name: Outlet_Type, dtype: int64

# %%
df.Outlet_Size.value_counts()
# Out:
# Medium    6537
# Small     5500
# High      2167
# Name: Outlet_Size, dtype: int64

# %% [markdown]
# # EDA

# %%
df.groupby('Outlet_Establishment_Year')['Item_Outlet_Sales'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('item_outlet_sales')
plt.title("itemsale vs establisbmentyr")
# Out:
# Text(0.5, 1.0, 'itemsale vs establisbmentyr')

# %%
columns=['Item_Identifier','Outlet_Identifier','Outlet_Establishment_Year']
df=df.drop(columns,axis=1)
df
# Out:
#        Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0             9.30          Low Fat         0.016047                  Dairy
# 1             5.92          Regular         0.019278            Soft Drinks
# 2            17.50          Low Fat         0.016760                   Meat
# 3            19.20          Regular         0.000000  Fruits and Vegetables
# 4             8.93          Low Fat         0.000000              Household
# ...            ...              ...              ...                    ...
# 14199        10.50          Regular         0.013496            Snack Foods
# 14200         7.60          Regular         0.142991          Starchy Foods
# 14201        10.00          Low Fat         0.073529     Health and Hygiene
# 14202        15.30          Regular         0.000000                 Canned
# 14203         9.50          Regular         0.104720                 Canned
#
#        Item_MRP Outlet_Size Outlet_Location_Type        Outlet_Type  \
# 0      249.8092      Medium               Tier 1  Supermarket Type1
# 1       48.2692      Medium               Tier 3  Supermarket Type2
# 2      141.6180      Medium               Tier 1  Supermarket Type1
# 3      182.0950      Medium               Tier 3      Grocery Store
# 4       53.8614        High               Tier 3  Supermarket Type1
# ...         ...         ...                  ...                ...
# 14199  141.3154       Small               Tier 1  Supermarket Type1
# 14200  169.1448      Medium               Tier 3  Supermarket Type2
# 14201  118.7440      Medium               Tier 2  Supermarket Type1
# 14202  214.6218      Medium               Tier 2  Supermarket Type1
# 14203   79.7960      Medium               Tier 2  Supermarket Type1
#
#        Item_Outlet_Sales
# 0              3735.1380
# 1               443.4228
# 2              2097.2700
# 3               732.3800
# 4               994.7052
# ...                  ...
# 14199                NaN
# 14200                NaN
# 14201                NaN
# 14202                NaN
# 14203                NaN
#
# [14204 rows x 9 columns]

# %%
categorical_features=[feature for feature in df.columns if df[feature].dtype=='O']
categorical_features
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
for feature in categorical_features:
    print('The feature is {} and number of categories are {}'.format(feature,len(df[feature].unique())))
# Out:
# The feature is Item_Fat_Content and number of categories are 5
# The feature is Item_Type and number of categories are 16
# The feature is Outlet_Size and number of categories are 3
# The feature is Outlet_Location_Type and number of categories are 3
# The feature is Outlet_Type and number of categories are 4

# %%
for feature in categorical_features:
    data=df.copy()
    data.groupby(feature)['Item_Outlet_Sales'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Item_Outlet_Sales')
    plt.title(feature)
    plt.show()

# %%
corre=df.corr()
corre
# Out:
#                    Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# Item_Weight           1.000000        -0.016493  0.022398           0.013116
# Item_Visibility      -0.016493         1.000000 -0.006351          -0.128625
# Item_MRP              0.022398        -0.006351  1.000000           0.567574
# Item_Outlet_Sales     0.013116        -0.128625  0.567574           1.000000

# %%
df.boxplot(column=['Item_Outlet_Sales'])
plt.show()

# %%
df.boxplot(column=['Item_MRP'])
plt.show()

# %%
df.boxplot(column=['Item_Weight'])
plt.show()

# %%
dublicate=df.duplicated()
print(dublicate.sum())
# Out:
# 0

# %%
dublicate
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14199    False
# 14200    False
# 14201    False
# 14202    False
# 14203    False
# Length: 14204, dtype: bool

# %%
sns.scatterplot(df['Outlet_Type'],df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.lineplot(df['Outlet_Type'],df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.lineplot(df['Item_Weight'],df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Item_Outlet_Sales'>

# %%
plt.scatter(df['Item_Outlet_Sales'],df['Item_Fat_Content'])

# %%
sns.lineplot(df['Item_Visibility'],df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_Outlet_Sales'>

# %%
discrete_feature=['Item_Weight','Item_Visibility','Item_MRP']
for feature in discrete_feature:
    df.groupby(feature)['Item_Outlet_Sales'].median().plot.bar()
    plt.xlabel('item_mrp')
    plt.ylabel('outletsale')
    plt.show()

# %%
df
# Out:
#        Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0             9.30          Low Fat         0.016047                  Dairy
# 1             5.92          Regular         0.019278            Soft Drinks
# 2            17.50          Low Fat         0.016760                   Meat
# 3            19.20          Regular         0.000000  Fruits and Vegetables
# 4             8.93          Low Fat         0.000000              Household
# ...            ...              ...              ...                    ...
# 14199        10.50          Regular         0.013496            Snack Foods
# 14200         7.60          Regular         0.142991          Starchy Foods
# 14201        10.00          Low Fat         0.073529     Health and Hygiene
# 14202        15.30          Regular         0.000000                 Canned
# 14203         9.50          Regular         0.104720                 Canned
#
#        Item_MRP Outlet_Size Outlet_Location_Type        Outlet_Type  \
# 0      249.8092      Medium               Tier 1  Supermarket Type1
# 1       48.2692      Medium               Tier 3  Supermarket Type2
# 2      141.6180      Medium               Tier 1  Supermarket Type1
# 3      182.0950      Medium               Tier 3      Grocery Store
# 4       53.8614        High               Tier 3  Supermarket Type1
# ...         ...         ...                  ...                ...
# 14199  141.3154       Small               Tier 1  Supermarket Type1
# 14200  169.1448      Medium               Tier 3  Supermarket Type2
# 14201  118.7440      Medium               Tier 2  Supermarket Type1
# 14202  214.6218      Medium               Tier 2  Supermarket Type1
# 14203   79.7960      Medium               Tier 2  Supermarket Type1
#
#        Item_Outlet_Sales
# 0              3735.1380
# 1               443.4228
# 2              2097.2700
# 3               732.3800
# 4               994.7052
# ...                  ...
# 14199                NaN
# 14200                NaN
# 14201                NaN
# 14202                NaN
# 14203                NaN
#
# [14204 rows x 9 columns]

# %%
continuous_feature=['Item_Fat_Content','Item_Type','Outlet_Size','Outlet_Location_Type','Outlet_Type']
for feature in continuous_feature:
    data=df.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("outletsales")
    plt.title(feature)
    plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Item_MRP',y='Item_Outlet_Sales',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Item_MRP',y='Outlet_Type',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Outlet_Type'>

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Item_Type',y='Item_MRP',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_MRP'>

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Item_Fat_Content',y='Item_MRP',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_MRP'>

# %%
sns.displot(df,x="Item_Fat_Content")

# %%
sns.displot(df,x="Item_Fat_Content",hue='Item_Type')

# %%
df.groupby('Item_Type').count().plot()
# Out:
# <AxesSubplot:xlabel='Item_Type'>

# %%
df.groupby('Outlet_Size').count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Outlet_Size'>

# %%
df.hist(bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'Item_Weight'}>,
#         <AxesSubplot:title={'center':'Item_Visibility'}>],
#        [<AxesSubplot:title={'center':'Item_MRP'}>,
#         <AxesSubplot:title={'center':'Item_Outlet_Sales'}>]], dtype=object)

# %%
sns.barplot(x="Outlet_Type", y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.barplot(x="Item_Type", y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.barplot(x="Outlet_Size", y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(test.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Item_Fat_Content',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Item_Outlet_Sales',hue='Outlet_Location_Type',data=train,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Item_Outlet_Sales',hue='Item_Fat_Content',data=train,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='count'>

# %%
sns.distplot(df['Item_Outlet_Sales'].dropna(),kde=False,color='darkred',bins=40)
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales'>

# %%
sns.distplot(df["Item_Outlet_Sales"])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
df['Outlet_Size'].hist(bins=25)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(corre, annot=True)
# Out:
# <AxesSubplot:>

# %%
X = data[["Item_Type","Item_Outlet_Sales"]]
#Visualise data points
plt.scatter(X["Item_Type"],X["Item_Outlet_Sales"],c='black')
plt.show()

# %%
sns.countplot(train.Outlet_Location_Type)
plt.show()

# %%
df
# Out:
#        Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0             9.30          Low Fat         0.016047                  Dairy
# 1             5.92          Regular         0.019278            Soft Drinks
# 2            17.50          Low Fat         0.016760                   Meat
# 3            19.20          Regular         0.000000  Fruits and Vegetables
# 4             8.93          Low Fat         0.000000              Household
# ...            ...              ...              ...                    ...
# 14199        10.50          Regular         0.013496            Snack Foods
# 14200         7.60          Regular         0.142991          Starchy Foods
# 14201        10.00          Low Fat         0.073529     Health and Hygiene
# 14202        15.30          Regular         0.000000                 Canned
# 14203         9.50          Regular         0.104720                 Canned
#
#        Item_MRP Outlet_Size Outlet_Location_Type        Outlet_Type  \
# 0      249.8092      Medium               Tier 1  Supermarket Type1
# 1       48.2692      Medium               Tier 3  Supermarket Type2
# 2      141.6180      Medium               Tier 1  Supermarket Type1
# 3      182.0950      Medium               Tier 3      Grocery Store
# 4       53.8614        High               Tier 3  Supermarket Type1
# ...         ...         ...                  ...                ...
# 14199  141.3154       Small               Tier 1  Supermarket Type1
# 14200  169.1448      Medium               Tier 3  Supermarket Type2
# 14201  118.7440      Medium               Tier 2  Supermarket Type1
# 14202  214.6218      Medium               Tier 2  Supermarket Type1
# 14203   79.7960      Medium               Tier 2  Supermarket Type1
#
#        Item_Outlet_Sales
# 0              3735.1380
# 1               443.4228
# 2              2097.2700
# 3               732.3800
# 4               994.7052
# ...                  ...
# 14199                NaN
# 14200                NaN
# 14201                NaN
# 14202                NaN
# 14203                NaN
#
# [14204 rows x 9 columns]

# %%
from sklearn import preprocessing
label_encoding = preprocessing.LabelEncoder()
df['Item_type1'] = label_encoding.fit_transform(df['Item_Type'].astype(str))
df['Item_Fat_Content1']=label_encoding.fit_transform(df['Item_Fat_Content'].astype(str))
df['Outlet_Location_Type1']=label_encoding.fit_transform(df['Outlet_Location_Type'].astype(str))
df['Outlet_Type1']=label_encoding.fit_transform(df['Outlet_Type'].astype(str))
df['Outlet_Size1']=label_encoding.fit_transform(df['Outlet_Size'].astype(str))
df.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Size Outlet_Location_Type        Outlet_Type  \
# 0  249.8092      Medium               Tier 1  Supermarket Type1
# 1   48.2692      Medium               Tier 3  Supermarket Type2
# 2  141.6180      Medium               Tier 1  Supermarket Type1
# 3  182.0950      Medium               Tier 3      Grocery Store
# 4   53.8614        High               Tier 3  Supermarket Type1
#
#    Item_Outlet_Sales  Item_type1  Item_Fat_Content1  Outlet_Location_Type1  \
# 0          3735.1380           4                  1                      0
# 1           443.4228          14                  2                      2
# 2          2097.2700          10                  1                      0
# 3           732.3800           6                  2                      2
# 4           994.7052           9                  1                      2
#
#    Outlet_Type1  Outlet_Size1
# 0             1             1
# 1             2             1
# 2             1             1
# 3             0             1
# 4             1             0

# %%
columns=['Item_Type','Item_Fat_Content','Outlet_Location_Type','Outlet_Type','Outlet_Size']
df=df.drop(columns,axis=1)
df
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales  Item_type1  \
# 0             9.30         0.016047  249.8092          3735.1380           4
# 1             5.92         0.019278   48.2692           443.4228          14
# 2            17.50         0.016760  141.6180          2097.2700          10
# 3            19.20         0.000000  182.0950           732.3800           6
# 4             8.93         0.000000   53.8614           994.7052           9
# ...            ...              ...       ...                ...         ...
# 14199        10.50         0.013496  141.3154                NaN          13
# 14200         7.60         0.142991  169.1448                NaN          15
# 14201        10.00         0.073529  118.7440                NaN           8
# 14202        15.30         0.000000  214.6218                NaN           3
# 14203         9.50         0.104720   79.7960                NaN           3
#
#        Item_Fat_Content1  Outlet_Location_Type1  Outlet_Type1  Outlet_Size1
# 0                      1                      0             1             1
# 1                      2                      2             2             1
# 2                      1                      0             1             1
# 3                      2                      2             0             1
# 4                      1                      2             1             0
# ...                  ...                    ...           ...           ...
# 14199                  2                      0             1             2
# 14200                  2                      2             2             1
# 14201                  1                      1             1             1
# 14202                  2                      1             1             1
# 14203                  2                      1             1             1
#
# [14204 rows x 9 columns]

# %%
df["Item_Outlet_Sales"]
# Out:
# 0        3735.1380
# 1         443.4228
# 2        2097.2700
# 3         732.3800
# 4         994.7052
#            ...
# 14199          NaN
# 14200          NaN
# 14201          NaN
# 14202          NaN
# 14203          NaN
# Name: Item_Outlet_Sales, Length: 14204, dtype: float64

# %% [markdown]
# # split train and test dataset

# %%
y = df['Item_Outlet_Sales']
y
# Out:
# 0        3735.1380
# 1         443.4228
# 2        2097.2700
# 3         732.3800
# 4         994.7052
#            ...
# 14199          NaN
# 14200          NaN
# 14201          NaN
# 14202          NaN
# 14203          NaN
# Name: Item_Outlet_Sales, Length: 14204, dtype: float64

# %%
X = df.drop(["Item_Outlet_Sales"],axis=1)
X
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Item_type1  Item_Fat_Content1  \
# 0             9.30         0.016047  249.8092           4                  1
# 1             5.92         0.019278   48.2692          14                  2
# 2            17.50         0.016760  141.6180          10                  1
# 3            19.20         0.000000  182.0950           6                  2
# 4             8.93         0.000000   53.8614           9                  1
# ...            ...              ...       ...         ...                ...
# 14199        10.50         0.013496  141.3154          13                  2
# 14200         7.60         0.142991  169.1448          15                  2
# 14201        10.00         0.073529  118.7440           8                  1
# 14202        15.30         0.000000  214.6218           3                  2
# 14203         9.50         0.104720   79.7960           3                  2
#
#        Outlet_Location_Type1  Outlet_Type1  Outlet_Size1
# 0                          0             1             1
# 1                          2             2             1
# 2                          0             1             1
# 3                          2             0             1
# 4                          2             1             0
# ...                      ...           ...           ...
# 14199                      0             1             2
# 14200                      2             2             1
# 14201                      1             1             1
# 14202                      1             1             1
# 14203                      1             1             1
#
# [14204 rows x 8 columns]

# %%
X
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Item_type1  Item_Fat_Content1  \
# 0             9.30         0.016047  249.8092           4                  1
# 1             5.92         0.019278   48.2692          14                  2
# 2            17.50         0.016760  141.6180          10                  1
# 3            19.20         0.000000  182.0950           6                  2
# 4             8.93         0.000000   53.8614           9                  1
# ...            ...              ...       ...         ...                ...
# 14199        10.50         0.013496  141.3154          13                  2
# 14200         7.60         0.142991  169.1448          15                  2
# 14201        10.00         0.073529  118.7440           8                  1
# 14202        15.30         0.000000  214.6218           3                  2
# 14203         9.50         0.104720   79.7960           3                  2
#
#        Outlet_Location_Type1  Outlet_Type1  Outlet_Size1
# 0                          0             1             1
# 1                          2             2             1
# 2                          0             1             1
# 3                          2             0             1
# 4                          2             1             0
# ...                      ...           ...           ...
# 14199                      0             1             2
# 14200                      2             2             1
# 14201                      1             1             1
# 14202                      1             1             1
# 14203                      1             1             1
#
# [14204 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)

# %%
X_train.shape, X_test.shape
# Out:
# ((11363, 8), (2841, 8))

# %%
X_train
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Item_type1  Item_Fat_Content1  \
# 529          7.560         0.063900  157.2630           5                  1
# 2678         6.260         0.016517  151.1366          10                  4
# 8754         7.435         0.141356  168.5158          15                  1
# 9881        18.200         0.058560  222.6456           9                  1
# 5586        20.600         0.045510  149.6392           8                  1
# ...            ...              ...       ...         ...                ...
# 5695        14.650         0.170664   56.4614           7                  1
# 8006        12.500         0.018849   96.7384           8                  1
# 1361         9.695         0.129009  226.9404           0                  2
# 1547        15.700         0.161317   57.5562           9                  1
# 13151        7.170         0.060066  130.9968           6                  2
#
#        Outlet_Location_Type1  Outlet_Type1  Outlet_Size1
# 529                        1             1             2
# 2678                       2             0             0
# 8754                       2             0             0
# 9881                       0             1             1
# 5586                       1             1             1
# ...                      ...           ...           ...
# 5695                       1             1             2
# 8006                       0             1             2
# 1361                       1             1             0
# 1547                       2             2             1
# 13151                      1             1             1
#
# [11363 rows x 8 columns]

# %%
y_train
# Out:
# 529      2503.4080
# 2678      453.4098
# 8754           NaN
# 9881           NaN
# 5586      894.8352
#            ...
# 5695     1436.7964
# 8006     2167.8448
# 1361     2700.4848
# 1547      829.5868
# 13151          NaN
# Name: Item_Outlet_Sales, Length: 11363, dtype: float64

# %% [markdown]
# # build different algorithm

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=3)

# %%
from sklearn.cluster import KMeans
kmean = KMeans()
kmean.fit(X_train,y_train)
# Out:
# KMeans()

# %%
y_pred = kmean.predict(X_test)
y_pred
# Out:
# array([0, 5, 3, ..., 0, 1, 1])

# %%
pd.DataFrame({"Actual value":y_test,"predicted value":y_pred})
# Out:
#        Actual value  predicted value
# 980       3547.3824                0
# 6926       354.2056                5
# 499       1298.3100                3
# 6960      1498.0500                7
# 1868      1244.3802                7
# ...             ...              ...
# 7087      1924.1620                3
# 7591      4339.0186                2
# 9988            NaN                0
# 11472           NaN                1
# 1574       126.5020                1
#
# [2841 rows x 2 columns]

# %%
kmean.labels_
# Out:
# array([0, 0, 7, ..., 2, 1, 3])

# %%
kmean.cluster_centers_
# Out:
# array([[1.27475481e+01, 6.75109020e-02, 1.49234560e+02, 7.43639053e+00,
#         1.33727811e+00, 1.10059172e+00, 1.19082840e+00, 1.25739645e+00],
#        [1.24482607e+01, 6.84089212e-02, 4.87093721e+01, 7.20305430e+00,
#         1.38009050e+00, 1.13461538e+00, 1.21662896e+00, 1.22115385e+00],
#        [1.28814166e+01, 6.75564384e-02, 2.22412082e+02, 7.04826863e+00,
#         1.40923400e+00, 1.11752361e+00, 1.21511018e+00, 1.22245540e+00],
#        [1.26722014e+01, 6.50688028e-02, 1.17519505e+02, 7.51568826e+00,
#         1.27479757e+00, 1.09159919e+00, 1.19331984e+00, 1.23431174e+00],
#        [1.33241129e+01, 6.34016825e-02, 1.89718319e+02, 7.61950147e+00,
#         1.42155425e+00, 1.09897361e+00, 1.18988270e+00, 1.24853372e+00],
#        [1.27645509e+01, 6.49618240e-02, 9.00566349e+01, 6.02745995e+00,
#         1.44736842e+00, 1.11842105e+00, 1.21624714e+00, 1.23340961e+00],
#        [1.27026518e+01, 6.74716207e-02, 2.52022771e+02, 7.43663472e+00,
#         1.33226837e+00, 1.11182109e+00, 1.21086262e+00, 1.22257721e+00],
#        [1.26714964e+01, 6.58981646e-02, 1.70264502e+02, 7.87015044e+00,
#         1.36421219e+00, 1.10926366e+00, 1.19239905e+00, 1.23594616e+00]])

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=3)
knn
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
std_data = sc.fit_transform(X_train)

# %%
from sklearn.cluster import KMeans
kmean = KMeans()
kmean.fit(X_train,y_train)
# Out:
# KMeans()

# %%
Centroids = kmean.cluster_centers_
Centroids
# Out:
# array([[1.26771793e+01, 6.51064385e-02, 1.17551660e+02, 7.51010101e+00,
#         1.27474747e+00, 1.09242424e+00, 1.19292929e+00, 1.23434343e+00],
#        [1.27679069e+01, 6.55285471e-02, 1.70697544e+02, 7.78090767e+00,
#         1.36384977e+00, 1.10954617e+00, 1.19170579e+00, 1.23630673e+00],
#        [1.24482607e+01, 6.84089212e-02, 4.87093721e+01, 7.20305430e+00,
#         1.38009050e+00, 1.13461538e+00, 1.21662896e+00, 1.22115385e+00],
#        [1.28871376e+01, 6.74978442e-02, 2.22429150e+02, 7.03991597e+00,
#         1.40966387e+00, 1.11659664e+00, 1.21428571e+00, 1.22268908e+00],
#        [1.27098904e+01, 6.73647446e-02, 1.49435368e+02, 7.48830409e+00,
#         1.33479532e+00, 1.10014620e+00, 1.19152047e+00, 1.25657895e+00],
#        [1.27026518e+01, 6.74716207e-02, 2.52022771e+02, 7.43663472e+00,
#         1.33226837e+00, 1.11182109e+00, 1.21086262e+00, 1.22257721e+00],
#        [1.27645509e+01, 6.49618240e-02, 9.00566349e+01, 6.02745995e+00,
#         1.44736842e+00, 1.11842105e+00, 1.21624714e+00, 1.23340961e+00],
#        [1.32746241e+01, 6.38136140e-02, 1.89983723e+02, 7.66541353e+00,
#         1.42631579e+00, 1.09849624e+00, 1.19097744e+00, 1.24887218e+00]])

# %%
df_Centroid = pd.DataFrame(Centroids)
df_Centroid
# Out:
#            0         1           2         3         4         5         6  \
# 0  12.677179  0.065106  117.551660  7.510101  1.274747  1.092424  1.192929
# 1  12.767907  0.065529  170.697544  7.780908  1.363850  1.109546  1.191706
# 2  12.448261  0.068409   48.709372  7.203054  1.380090  1.134615  1.216629
# 3  12.887138  0.067498  222.429150  7.039916  1.409664  1.116597  1.214286
# 4  12.709890  0.067365  149.435368  7.488304  1.334795  1.100146  1.191520
# 5  12.702652  0.067472  252.022771  7.436635  1.332268  1.111821  1.210863
# 6  12.764551  0.064962   90.056635  6.027460  1.447368  1.118421  1.216247
# 7  13.274624  0.063814  189.983723  7.665414  1.426316  1.098496  1.190977
#
#           7
# 0  1.234343
# 1  1.236307
# 2  1.221154
# 3  1.222689
# 4  1.256579
# 5  1.222577
# 6  1.233410
# 7  1.248872

# %%
y_test
# Out:
# 980      3547.3824
# 6926      354.2056
# 499      1298.3100
# 6960     1498.0500
# 1868     1244.3802
#            ...
# 7087     1924.1620
# 7591     4339.0186
# 9988           NaN
# 11472          NaN
# 1574      126.5020
# Name: Item_Outlet_Sales, Length: 2841, dtype: float64

# %%
y_pred = kmean.predict(X_test)
y_pred
# Out:
# array([4, 6, 0, ..., 4, 2, 2])

# %%
SSE = []
for cluster in range(1,10):
    kmeans = KMeans(n_clusters = cluster)
    kmeans.fit(std_data)
    SSE.append(kmeans.inertia_)

# converting the results into a dataframe and plotting them
frame = pd.DataFrame({'Cluster':range(1,10), 'SSE':SSE})
plt.figure(figsize=(12,6))
plt.plot(frame['Cluster'], frame['SSE'], marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %%
kmeans = KMeans(n_clusters = 4)
kmeans.fit(std_data)
# Out:
# KMeans(n_clusters=4)

# %%
kmeans.labels_
# Out:
# array([1, 3, 3, ..., 3, 0, 1])

# %%
plt.scatter(std_data[:,2], std_data[:,3], c=kmeans.labels_)
plt.show()

# %%
result = pd.DataFrame(X,y)

# %%
result["Item_Outlet_Sales"] = y_test
result
# Out:
#                    Item_Weight  Item_Visibility  Item_MRP  Item_type1  \
# Item_Outlet_Sales
# 3735.1380                  NaN              NaN       NaN         NaN
# 443.4228                   NaN              NaN       NaN         NaN
# 2097.2700                  NaN              NaN       NaN         NaN
# 732.3800                   NaN              NaN       NaN         NaN
# 994.7052                   NaN              NaN       NaN         NaN
# ...                        ...              ...       ...         ...
# NaN                        NaN              NaN       NaN         NaN
# NaN                        NaN              NaN       NaN         NaN
# NaN                        NaN              NaN       NaN         NaN
# NaN                        NaN              NaN       NaN         NaN
# NaN                        NaN              NaN       NaN         NaN
#
#                    Item_Fat_Content1  Outlet_Location_Type1  Outlet_Type1  \
# Item_Outlet_Sales
# 3735.1380                        NaN                    NaN           NaN
# 443.4228                         NaN                    NaN           NaN
# 2097.2700                        NaN                    NaN           NaN
# 732.3800                         NaN                    NaN           NaN
# 994.7052                         NaN                    NaN           NaN
# ...                              ...                    ...           ...
# NaN                              NaN                    NaN           NaN
# NaN                              NaN                    NaN           NaN
# NaN                              NaN                    NaN           NaN
# NaN                              NaN                    NaN           NaN
# NaN                              NaN                    NaN           NaN
#
#                    Outlet_Size1  Item_Outlet_Sales
# Item_Outlet_Sales
# 3735.1380                   NaN                NaN
# 443.4228                    NaN                NaN
# 2097.2700                   NaN                NaN
# 732.3800                    NaN                NaN
# 994.7052                    NaN                NaN
# ...                         ...                ...
# NaN                         NaN                NaN
# NaN                         NaN                NaN
# NaN                         NaN                NaN
# NaN                         NaN                NaN
# NaN                         NaN                NaN
#
# [14204 rows x 9 columns]

# %%
X = df.drop(['Item_Outlet_Sales'],axis=1)

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(X)

# %%
kmean = KMeans(n_clusters=2)
kmean.fit(scaled_data)
# Out:
# KMeans(n_clusters=2)

# %%
plt.scatter(scaled_data[:, 0], scaled_data[:, 1])

# %%
kmean.labels_
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
plt.scatter(scaled_data[:, 0], scaled_data[:, 1], c=kmean.labels_)

# %%
data = kmean.transform(scaled_data)

# %%
kmean.labels_
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
kmean.cluster_centers_
# Out:
# array([[ 2.32511593e-03, -8.38622586e-02,  1.26441922e-03,
#          6.47157560e-03,  3.53608037e-03,  9.81872803e-01,
#          8.23685806e-01, -9.27430900e-01],
#        [-1.37237026e-03,  4.94986372e-02, -7.46307449e-04,
#         -3.81976563e-03, -2.08712670e-03, -5.79538000e-01,
#         -4.86170127e-01,  5.47404355e-01]])

# %%
result = pd.DataFrame(X,y)
result["Predicted_Item_Outlet_Sales"] = kmean.labels_

# %%
result["Original_Item_Outlet_Sales"] = y

# %%
result
# Out:
#                    Item_Weight  Item_Visibility  Item_MRP  Item_type1  \
# Item_Outlet_Sales
# 3735.1380                  NaN              NaN       NaN         NaN
# 443.4228                   NaN              NaN       NaN         NaN
# 2097.2700                  NaN              NaN       NaN         NaN
# 732.3800                   NaN              NaN       NaN         NaN
# 994.7052                   NaN              NaN       NaN         NaN
# ...                        ...              ...       ...         ...
# NaN                        NaN              NaN       NaN         NaN
# NaN                        NaN              NaN       NaN         NaN
# NaN                        NaN              NaN       NaN         NaN
# NaN                        NaN              NaN       NaN         NaN
# NaN                        NaN              NaN       NaN         NaN
#
#                    Item_Fat_Content1  Outlet_Location_Type1  Outlet_Type1  \
# Item_Outlet_Sales
# 3735.1380                        NaN                    NaN           NaN
# 443.4228                         NaN                    NaN           NaN
# 2097.2700                        NaN                    NaN           NaN
# 732.3800                         NaN                    NaN           NaN
# 994.7052                         NaN                    NaN           NaN
# ...                              ...                    ...           ...
# NaN                              NaN                    NaN           NaN
# NaN                              NaN                    NaN           NaN
# NaN                              NaN                    NaN           NaN
# NaN                              NaN                    NaN           NaN
# NaN                              NaN                    NaN           NaN
#
#                    Outlet_Size1  Predicted_Item_Outlet_Sales  \
# Item_Outlet_Sales
# 3735.1380                   NaN                            1
# 443.4228                    NaN                            0
# 2097.2700                   NaN                            1
# 732.3800                    NaN                            1
# 994.7052                    NaN                            0
# ...                         ...                          ...
# NaN                         NaN                            1
# NaN                         NaN                            0
# NaN                         NaN                            1
# NaN                         NaN                            1
# NaN                         NaN                            1
#
#                    Original_Item_Outlet_Sales
# Item_Outlet_Sales
# 3735.1380                                 NaN
# 443.4228                                  NaN
# 2097.2700                                 NaN
# 732.3800                                  NaN
# 994.7052                                  NaN
# ...                                       ...
# NaN                                       NaN
# NaN                                       NaN
# NaN                                       NaN
# NaN                                       NaN
# NaN                                       NaN
#
# [14204 rows x 10 columns]

# %%
y_pred
# Out:
# array([4, 6, 0, ..., 4, 2, 2])

# %%
df
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales  Item_type1  \
# 0             9.30         0.016047  249.8092          3735.1380           4
# 1             5.92         0.019278   48.2692           443.4228          14
# 2            17.50         0.016760  141.6180          2097.2700          10
# 3            19.20         0.000000  182.0950           732.3800           6
# 4             8.93         0.000000   53.8614           994.7052           9
# ...            ...              ...       ...                ...         ...
# 14199        10.50         0.013496  141.3154                NaN          13
# 14200         7.60         0.142991  169.1448                NaN          15
# 14201        10.00         0.073529  118.7440                NaN           8
# 14202        15.30         0.000000  214.6218                NaN           3
# 14203         9.50         0.104720   79.7960                NaN           3
#
#        Item_Fat_Content1  Outlet_Location_Type1  Outlet_Type1  Outlet_Size1
# 0                      1                      0             1             1
# 1                      2                      2             2             1
# 2                      1                      0             1             1
# 3                      2                      2             0             1
# 4                      1                      2             1             0
# ...                  ...                    ...           ...           ...
# 14199                  2                      0             1             2
# 14200                  2                      2             2             1
# 14201                  1                      1             1             1
# 14202                  2                      1             1             1
# 14203                  2                      1             1             1
#
# [14204 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
print(y_train.shape,X_train.shape)
# Out:
# (11363,) (11363, 8)

# %%
X_train
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Item_type1  Item_Fat_Content1  \
# 4600        19.200         0.049081  147.7734           6                  1
# 11458       16.000         0.090338  140.3154           4                  1
# 4684         8.195         0.031467   91.8462           0                  1
# 9211        14.300         0.049777  211.7586          10                  2
# 11107       16.500         0.011728  164.5184           9                  1
# ...            ...              ...       ...         ...                ...
# 1477        15.850         0.043235   38.3164          15                  1
# 8384        10.100         0.045654   35.6848          13                  2
# 11957       13.850         0.057864  115.4492           7                  1
# 12467       15.850         0.122128   59.5220           0                  2
# 4967        15.600         0.066830  185.5924          11                  1
#
#        Outlet_Location_Type1  Outlet_Type1  Outlet_Size1
# 4600                       2             3             1
# 11458                      2             2             1
# 4684                       1             1             1
# 9211                       1             1             0
# 11107                      0             0             2
# ...                      ...           ...           ...
# 1477                       0             1             2
# 8384                       2             1             0
# 11957                      2             0             2
# 12467                      2             2             1
# 4967                       0             1             1
#
# [11363 rows x 8 columns]

# %%
from sklearn.cluster import KMeans
kmean = KMeans()
kmean.fit(X_train,y_train)
# Out:
# KMeans()

# %%
y_pred = kmean.predict(X_test)
y_pred
# Out:
# array([6, 5, 4, ..., 2, 6, 0])

# %%
kmean.labels_
# Out:
# array([5, 5, 4, ..., 2, 0, 6])

# %%
kmean.cluster_centers_
# Out:
# array([[1.25541218e+01, 6.94571879e-02, 4.88454288e+01, 7.23796034e+00,
#         1.36713881e+00, 1.10878187e+00, 1.19490085e+00, 1.23682720e+00],
#        [1.28850154e+01, 6.70321857e-02, 2.22257069e+02, 7.21604938e+00,
#         1.39711934e+00, 1.11316872e+00, 1.20061728e+00, 1.23456790e+00],
#        [1.28166119e+01, 6.51182150e-02, 1.17525679e+02, 7.47549267e+00,
#         1.28044467e+00, 1.10156645e+00, 1.18948964e+00, 1.24810510e+00],
#        [1.27657855e+01, 6.52539761e-02, 1.71195773e+02, 7.64433812e+00,
#         1.36124402e+00, 1.11881978e+00, 1.20175439e+00, 1.22009569e+00],
#        [1.28177816e+01, 6.37989222e-02, 8.98821779e+01, 6.10057471e+00,
#         1.44712644e+00, 1.11206897e+00, 1.20459770e+00, 1.22816092e+00],
#        [1.27766148e+01, 6.63604719e-02, 1.49532155e+02, 7.46148410e+00,
#         1.34134276e+00, 1.11519435e+00, 1.18586572e+00, 1.25724382e+00],
#        [1.32367184e+01, 6.43334535e-02, 1.90324827e+02, 7.63304888e+00,
#         1.40418929e+00, 1.12412723e+00, 1.20480993e+00, 1.23351435e+00],
#        [1.26556639e+01, 6.69738895e-02, 2.52357857e+02, 7.33298209e+00,
#         1.33508957e+00, 1.10432034e+00, 1.18756586e+00, 1.23076923e+00]])

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=3)

# %%
train = pd.read_csv("Train.csv")
test = pd.read_csv("Test.csv")
# print(train.head())
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
train.Item_Identifier
# Out:
# 0       FDA15
# 1       DRC01
# 2       FDN15
# 3       FDX07
# 4       NCD19
#         ...
# 8518    FDF22
# 8519    FDS36
# 8520    NCJ29
# 8521    FDN46
# 8522    DRG01
# Name: Item_Identifier, Length: 8523, dtype: object

# %%
idsUnique = len(set(train.Item_Identifier))
idsUnique
# Out:
# 1559

# %%
# Check for duplicates
idsUnique = len(set(train.Item_Identifier))
idsTotal = train.shape[0]
idsDupli = idsTotal - idsUnique

# %%
print("There are " + str(idsDupli) + " duplicate IDs for " + str(idsTotal) + " total entries")
# Out:
# There are 6964 duplicate IDs for 8523 total entries

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(12, 7))
sns.distplot(train.Item_Outlet_Sales, bins=25)
plt.ticklabel_format(style='plain', axis='x', scilimits=(0, 1))
plt.xlabel("Item_Outlet_Sales")
plt.ylabel("Number of Sales")
plt.title("Item_Outlet_Sales Distribution")
plt.show()  # Distribution of item outlet sales

# %%
sns.countplot(train.Item_Fat_Content)
plt.show()  # Distribution of fat content

# %%
sns.countplot(train.Item_Type)
plt.xticks(rotation=90)
sns.countplot(train.Outlet_Size)
plt.show()  # Distribution of outlet size

# %%
sns.countplot(train.Outlet_Location_Type)
plt.show()  # Distribution of outlet location type

# %%
sns.countplot(train.Outlet_Type)
plt.xticks(rotation=90)
plt.show()  # Distribution of outlet type

# %%
# Join Train and Test Dataset

# Create source column to later separate the data easily
train['source'] = 'train'
test['source'] = 'test'

# %%
train.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'source'],
#       dtype='object')

# %%
data = pd.concat([train, test], ignore_index=True)
print(train.shape, test.shape, data.shape)
# aggfunc is mean by default and ignores NaN by defaul
# Out:
# (8523, 13) (5681, 12) (14204, 13)

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales source
# 0  Supermarket Type1          3735.1380  train
# 1  Supermarket Type2           443.4228  train
# 2  Supermarket Type1          2097.2700  train
# 3      Grocery Store           732.3800  train
# 4  Supermarket Type1           994.7052  train

# %%
item_avg_weight = data.pivot_table(values='Item_Weight', index='Item_Identifier')  # Create table with identifiers and its weights and ignores the NaN values

# %%
def impute_weight(cols):  # Filling null values with mean
    Weight = cols[0]
    Identifier = cols[1]

    if pd.isnull(Weight):
        return item_avg_weight['Item_Weight'][item_avg_weight.index == Identifier]
    else:
        return Weight

# %%
print ('Orignal missing: %d' % sum(data['Item_Weight'].isnull()))
print (data['Item_Weight'].mean())
# Out:
# Orignal missing: 2439
# 12.792854228644991

# %%
data['Item_Weight'] = data[['Item_Weight', 'Item_Identifier']].apply(impute_weight, axis=1).astype(float)

print ('Final missing: %d' % sum(data['Item_Weight'].isnull()))
# Out:
# Final missing: 0

# %%
#print (data['Item_Weight'].mean())
from scipy.stats import mode

# Determing the mode for each
outlet_size_mode = data.pivot_table(values='Outlet_Size', columns='Outlet_Type', aggfunc=lambda x: x.mode())

# %%
def impute_size_mode(cols):  # Same as above but using mode
    Size = cols[0]
    Type = cols[1]
    if pd.isnull(Size):
        return outlet_size_mode.loc['Outlet_Size'][outlet_size_mode.columns == Type][0]
    else:
        return Size

# %%
print ('Orignal missing: %d' % sum(data['Outlet_Size'].isnull()))
data['Outlet_Size'] = data[['Outlet_Size', 'Outlet_Type']].apply(impute_size_mode, axis=1)
print ('Final missing: %d' % sum(data['Outlet_Size'].isnull()))

visibility_item_avg = data.pivot_table(values='Item_Visibility', index='Item_Identifier')
# Out:
# Orignal missing: 4016
# Final missing: 0

# %%
def impute_visibility_mean(cols):
    visibility = cols[0]
    item = cols[1]
    if visibility == 0:
        return visibility_item_avg['Item_Visibility'][visibility_item_avg.index == item]
    else:
        return visibility

# %%
print ('Original zeros: %d' % sum(data['Item_Visibility'] == 0))
data['Item_Visibility'] = data[['Item_Visibility', 'Item_Identifier']].apply(impute_visibility_mean, axis=1).astype(float)

print ('Final zeros: %d' % sum(data['Item_Visibility'] == 0))
# Out:
# Original zeros: 879
# Final zeros: 0

# %%
# Remember the data is from 2013
data['Outlet_Years'] = 2013 - data['Outlet_Establishment_Year']
data['Outlet_Years'].describe()
# Out:
# count    14204.000000
# mean        15.169319
# std          8.371664
# min          4.000000
# 25%          9.000000
# 50%         14.000000
# 75%         26.000000
# max         28.000000
# Name: Outlet_Years, dtype: float64

# %%
# Get the first two characters of ID:
data['Item_Type_Combined'] = data['Item_Identifier'].apply(lambda x: x[0:2])

# %%
# Rename them to more intuitive categories:
data['Item_Type_Combined'] = data['Item_Type_Combined'].map({'FD': 'Food', 'NC': 'Non-Consumable', 'DR': 'Drinks'})

data['Item_Type_Combined'].value_counts()
# Out:
# Food              10201
# Non-Consumable     2686
# Drinks             1317
# Name: Item_Type_Combined, dtype: int64

# %%
data['Item_Fat_Content'] = data['Item_Fat_Content'].replace({'LF': 'Low Fat', 'reg': 'Regular',
                                                             'low fat': 'Low Fat'})

print(data['Item_Fat_Content'].value_counts())
# Out:
# Low Fat    9185
# Regular    5019
# Name: Item_Fat_Content, dtype: int64

# %%
# Mark non-consumables as separate category in low_fat:

data.loc[data['Item_Type_Combined'] == "Non-Consumable", 'Item_Fat_Content'] = "Non-Edible"

data['Item_Fat_Content'].value_counts()
# Out:
# Low Fat       6499
# Regular       5019
# Non-Edible    2686
# Name: Item_Fat_Content, dtype: int64

# %%
def func(x): return x['Item_Visibility'] / visibility_item_avg['Item_Visibility'][visibility_item_avg.index == x['Item_Identifier']][0]

# %%
data['Item_Visibility_MeanRatio'] = data.apply(func, axis=1).astype(float)
data['Item_Visibility_MeanRatio'].describe()
# Out:
# count    14204.000000
# mean         1.061884
# std          0.235907
# min          0.844563
# 25%          0.925131
# 50%          0.999070
# 75%          1.042007
# max          3.010094
# Name: Item_Visibility_MeanRatio, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# New variable for outlet
data['Outlet'] = le.fit_transform(data['Outlet_Identifier'])

var_mod = ['Item_Fat_Content', 'Outlet_Location_Type', 'Outlet_Size', 'Item_Type_Combined', 'Outlet_Type', 'Outlet']

# %%
for i in var_mod:
    data[i] = le.fit_transform(data[i])

# %%
# Exporting the data back

# Drop the columns which have been converted to different types:
data.drop(['Item_Type', 'Outlet_Establishment_Year'], axis=1, inplace=True)

# %%
# Divide into test and train:
train = data.loc[data['source'] == "train"]
test = data.loc[data['source'] == "test"]

# %%
# Drop unnecessary columns:
test.drop(['Item_Outlet_Sales', 'source'], axis=1, inplace=True)
train.drop(['source'], axis=1, inplace=True)

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           FDA15         9.30                 0         0.016047  249.8092
# 1           DRC01         5.92                 2         0.019278   48.2692
# 2           FDN15        17.50                 0         0.016760  141.6180
# 3           FDX07        19.20                 2         0.017834  182.0950
# 4           NCD19         8.93                 1         0.009780   53.8614
#
#   Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0            OUT049            1                     0            1
# 1            OUT018            1                     2            2
# 2            OUT049            1                     0            1
# 3            OUT010            2                     2            0
# 4            OUT013            0                     2            1
#
#    Item_Outlet_Sales  Outlet_Years  Item_Type_Combined  \
# 0          3735.1380            14                   1
# 1           443.4228             4                   0
# 2          2097.2700            14                   1
# 3           732.3800            15                   1
# 4           994.7052            26                   2
#
#    Item_Visibility_MeanRatio  Outlet
# 0                   0.931078       9
# 1                   0.933420       3
# 2                   0.960069       9
# 3                   1.000000       0
# 4                   1.000000       1

# %%
X = train.drop(['Item_Outlet_Sales','Item_Identifier', 'Outlet_Identifier'],axis=1)
y = train["Item_Outlet_Sales"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)
y_train
# Out:
# 1414    3420.8804
# 5756    3628.6100
# 8496    3715.1640
# 4856    5313.0840
# 5603     169.7790
#           ...
# 6290    2314.9866
# 8073    1031.9900
# 8085    3528.7400
# 5673    3243.7776
# 5280    1428.1410
# Name: Item_Outlet_Sales, Length: 6818, dtype: float64

# %%
x_train.shape
# Out:
# (6818, 11)

# %%
from sklearn.linear_model import LinearRegression
lreg = LinearRegression()
lreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lreg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
print("mean squared error",mean_squared_error(y_pred,y_test))
print("mean absolute error",mean_absolute_error(y_pred,y_test))  #Hyperparameter tuning
# Out:
# mean squared error 1392670.8329437496
# mean absolute error 880.5171563349451

# %%
from sklearn.tree import DecisionTreeRegressor
DT = DecisionTreeRegressor(max_depth=109, min_samples_leaf=70)
DT.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=109, min_samples_leaf=70)

# %%
DTy_pred = DT.predict(x_test)
print("mean squared error",mean_squared_error(DTy_pred,y_test))
print("mean absolute error",mean_absolute_error(DTy_pred,y_test))#1198459.1423844793 mean absolute error 767
# Out:
# mean squared error 1258038.9751863978
# mean absolute error 776.1233273413472

# %%
RF = DecisionTreeRegressor(max_depth=5, min_samples_leaf=60)
RF.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_leaf=60)

# %%
RFy_pred = RF.predict(x_test)
print("mean squared error",mean_squared_error(RFy_pred,y_test))
print("mean absolute error",mean_absolute_error(RFy_pred,y_test))
# Out:
# mean squared error 1202681.5723050132
# mean absolute error 761.2679649612247

# %%
from sklearn.cluster import KMeans
kmean = KMeans()
kmean.fit(x_train,y_train)
# Out:
# KMeans()

# %%
y_pred = kmean.predict(x_test)
y_pred
# Out:
# array([6, 4, 1, ..., 2, 1, 7])

# %%
kmean.labels_
# Out:
# array([4, 2, 6, ..., 5, 0, 1])

# %%
kmean.cluster_centers_
# Out:
# array([[1.31840325e+01, 9.09246575e-01, 7.03795928e-02, 2.22497570e+02,
#         1.47260274e+00, 1.08390411e+00, 1.19006849e+00, 1.52037671e+01,
#         1.07020548e+00, 1.05459389e+00, 4.83219178e+00],
#        [1.26788502e+01, 9.29468599e-01, 6.61594668e-02, 8.99969329e+01,
#         1.41739130e+00, 1.08985507e+00, 1.21159420e+00, 1.56589372e+01,
#         1.05314010e+00, 1.05784302e+00, 4.80966184e+00],
#        [1.28316148e+01, 8.62440191e-01, 7.05687546e-02, 1.48973417e+02,
#         1.47607656e+00, 1.04784689e+00, 1.17344498e+00, 1.54904306e+01,
#         1.08732057e+00, 1.06065114e+00, 4.88397129e+00],
#        [1.26196670e+01, 9.22138837e-01, 7.23703199e-02, 4.86878735e+01,
#         1.45309568e+00, 1.13696060e+00, 1.20075047e+00, 1.53180113e+01,
#         1.05253283e+00, 1.07293516e+00, 4.64165103e+00],
#        [1.26711259e+01, 8.40425532e-01, 7.04805289e-02, 2.53339418e+02,
#         1.44858156e+00, 1.13475177e+00, 1.20921986e+00, 1.47730496e+01,
#         1.16666667e+00, 1.05693006e+00, 4.68439716e+00],
#        [1.28568519e+01, 9.19540230e-01, 6.80107345e-02, 1.70234940e+02,
#         1.46743295e+00, 1.15708812e+00, 1.22349936e+00, 1.48071520e+01,
#         1.09323116e+00, 1.05457865e+00, 4.66922095e+00],
#        [1.33669875e+01, 9.56250000e-01, 6.86779586e-02, 1.89978260e+02,
#         1.45125000e+00, 1.13125000e+00, 1.21000000e+00, 1.54075000e+01,
#         1.05500000e+00, 1.07018449e+00, 4.69125000e+00],
#        [1.28480435e+01, 8.39130435e-01, 6.91221835e-02, 1.17298844e+02,
#         1.46434783e+00, 1.09739130e+00, 1.17739130e+00, 1.48591304e+01,
#         1.16086957e+00, 1.05811940e+00, 4.76521739e+00]])
